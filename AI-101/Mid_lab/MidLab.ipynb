# %%
name=str(input('Enter your name: '))
age=str(input("Enter your age: "))

print(f"My name is {name} and my age is {age}")
# Out:
# Enter your name: waqas
# Enter your age: 29
# My name is waqas and my age is 29
